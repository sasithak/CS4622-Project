# %%
# Mounting Google Drive to access data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Loading data
import pandas as pd
train = pd.read_csv("/content/drive/My Drive/Semester7/ML/Project/Layer_7/train.csv")
valid = pd.read_csv("/content/drive/My Drive/Semester7/ML/Project/Layer_7/valid.csv")
test = pd.read_csv("/content/drive/My Drive/Semester7/ML/Project/Layer_7/test.csv")

# %%
train.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0   0.186257  -0.058807   0.024632  -0.163933  -0.146699   0.035889
# 1   0.063431  -0.023597   0.068057  -0.252915  -0.061094  -0.027316
# 2   0.034962   0.035816  -0.029753  -0.094607  -0.017576  -0.053074
# 3   0.033772   0.085612   0.067488  -0.073953  -0.180646  -0.024512
# 4   0.134305   0.062096   0.106920  -0.089327   0.117093  -0.077107
#
#    feature_7  feature_8  feature_9  feature_10  ...  feature_763  feature_764  \
# 0   0.111708  -0.162861   0.028249   -0.098063  ...     0.055629    -0.010358
# 1   0.135747  -0.168147   0.091236   -0.078473  ...    -0.014893     0.071721
# 2   0.040121  -0.007932   0.097872   -0.024042  ...     0.012415     0.015215
# 3   0.242879  -0.023374  -0.059999    0.002006  ...    -0.078246    -0.032903
# 4   0.152579   0.047529  -0.015998   -0.110657  ...    -0.094629     0.069718
#
#    feature_765  feature_766  feature_767  feature_768  label_1  label_2  \
# 0     0.125754     0.011648     0.079197     0.093215       45      NaN
# 1     0.018918     0.100032    -0.083042     0.088615       45      NaN
# 2     0.083808     0.031312    -0.056277     0.064702       45      NaN
# 3     0.082949    -0.020659     0.082274    -0.050164       45      NaN
# 4     0.014379     0.048124     0.007586    -0.016980       45      NaN
#
#    label_3  label_4
# 0        1        6
# 1        1        6
# 2        1        6
# 3        1        6
# 4        1        6
#
# [5 rows x 772 columns]

# %%
valid.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0   0.085129   0.000378  -0.029872  -0.104609  -0.191291  -0.025511
# 1   0.222652  -0.094210  -0.056387  -0.210214  -0.294624  -0.032355
# 2   0.072147   0.023575  -0.017664  -0.070988  -0.098729   0.018534
# 3   0.026623   0.052005  -0.006921  -0.075105  -0.074829  -0.031380
# 4   0.112069   0.113702   0.044343   0.010162  -0.169193  -0.099847
#
#    feature_7  feature_8  feature_9  feature_10  ...  feature_763  feature_764  \
# 0   0.029381   0.006177   0.079207   -0.012729  ...    -0.026701     0.003306
# 1  -0.069078  -0.172146   0.056509   -0.126757  ...    -0.041096     0.013654
# 2   0.028282  -0.064789   0.094686   -0.067313  ...    -0.064602    -0.018653
# 3   0.012402  -0.043555   0.073825   -0.050979  ...    -0.005655     0.015477
# 4   0.195957   0.051861   0.024582    0.001314  ...    -0.118097    -0.043349
#
#    feature_765  feature_766  feature_767  feature_768  label_1  label_2  \
# 0     0.052219     0.000784     0.004527     0.102033       45      NaN
# 1     0.142623    -0.011882     0.005219     0.143616       45      NaN
# 2     0.013636    -0.078994     0.060903     0.064752       45      NaN
# 3     0.064209     0.025045    -0.049599     0.078412       45      NaN
# 4     0.036754    -0.023065     0.007358    -0.132566       45      NaN
#
#    label_3  label_4
# 0        1        6
# 1        1        6
# 2        1        6
# 3        1        6
# 4        1        6
#
# [5 rows x 772 columns]

# %%
test.head()
# Out:
#    ID  feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0   1   0.187868  -0.009268   0.039846  -0.102515  -0.109121  -0.079769
# 1   2   0.122119   0.019015   0.134483   0.007949  -0.157884  -0.033332
# 2   3   0.079187   0.146195  -0.001316  -0.085596  -0.261093  -0.021620
# 3   4   0.231196   0.021558   0.215534  -0.210258  -0.158189   0.041621
# 4   5   0.020412   0.063732  -0.065506  -0.089598  -0.130788  -0.018809
#
#    feature_7  feature_8  feature_9  ...  feature_759  feature_760  \
# 0   0.061295  -0.042890   0.099860  ...     0.043647     0.061174
# 1   0.044334  -0.016869  -0.014088  ...    -0.179798    -0.027611
# 2   0.268898  -0.103950   0.068976  ...    -0.075460     0.037346
# 3   0.240254  -0.068112  -0.017550  ...     0.083334     0.141642
# 4   0.119304  -0.057494   0.094714  ...    -0.001969    -0.003025
#
#    feature_761  feature_762  feature_763  feature_764  feature_765  \
# 0     0.026771    -0.092734    -0.052383    -0.055526     0.029101
# 1     0.240023    -0.005648    -0.057537     0.023922    -0.038126
# 2     0.124254    -0.369695    -0.056773    -0.028471     0.019971
# 3    -0.007219     0.031547    -0.010762    -0.169036    -0.030963
# 4    -0.021156    -0.136993    -0.003615     0.036371     0.048715
#
#    feature_766  feature_767  feature_768
# 0     0.041857    -0.027872     0.099500
# 1    -0.015171    -0.006270    -0.003790
# 2    -0.065683    -0.047366    -0.121744
# 3     0.086698     0.114194    -0.036775
# 4    -0.002688    -0.016957    -0.004331
#
# [5 rows x 769 columns]

# %% [markdown]
# ##Distribution of labels

# %% [markdown]
# #Handling Missing Values
#
# ##Missing values in training data

# %%
# Check for missing values in each label
labels = ["label_1", "label_2", "label_3", "label_4"]
train[labels].isnull().sum()
# Out:
# label_1      0
# label_2    480
# label_3      0
# label_4      0
# dtype: int64

# %%
len(train["label_2"])
# Out:
# 28520

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
columns = ["label_2"]
imputer.fit(train[columns])

# Insert the missing values with the mean with the nearest integer
train[columns] = imputer.transform(train[columns]).round().astype("int")

# Recheck for missing values in each label to confirm whether there are no missing values left
train[labels].isnull().sum()
# Out:
# label_1    0
# label_2    0
# label_3    0
# label_4    0
# dtype: int64

# %% [markdown]
# ##Missing values in validation data

# %%
valid[labels].isnull().sum()
# Out:
# label_1     0
# label_2    14
# label_3     0
# label_4     0
# dtype: int64

# %%
len(valid["label_2"])
# Out:
# 750

# %%
imputer = SimpleImputer(strategy='mean')
columns = ["label_2"]
imputer.fit(valid[columns])

# Insert the missing values with the mean with the nearest integer
valid[columns] = imputer.transform(valid[columns]).round().astype("int")
valid[labels].isnull().sum()
# Out:
# label_1    0
# label_2    0
# label_3    0
# label_4    0
# dtype: int64

# %% [markdown]
# #Label 1 - Speaker ID

# %%
# Split X and Y
x_label_1 = train.iloc[:, : -4]
y_label_1 = train["label_1"]
x_valid_label_1 = valid.iloc[:, : -4]
y_valid_label_1 = valid["label_1"]

# %%
x_label_1.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0   0.186257  -0.058807   0.024632  -0.163933  -0.146699   0.035889
# 1   0.063431  -0.023597   0.068057  -0.252915  -0.061094  -0.027316
# 2   0.034962   0.035816  -0.029753  -0.094607  -0.017576  -0.053074
# 3   0.033772   0.085612   0.067488  -0.073953  -0.180646  -0.024512
# 4   0.134305   0.062096   0.106920  -0.089327   0.117093  -0.077107
#
#    feature_7  feature_8  feature_9  feature_10  ...  feature_759  feature_760  \
# 0   0.111708  -0.162861   0.028249   -0.098063  ...    -0.135802     0.101059
# 1   0.135747  -0.168147   0.091236   -0.078473  ...    -0.032524     0.012977
# 2   0.040121  -0.007932   0.097872   -0.024042  ...    -0.016680    -0.015495
# 3   0.242879  -0.023374  -0.059999    0.002006  ...    -0.219269     0.065505
# 4   0.152579   0.047529  -0.015998   -0.110657  ...    -0.228570     0.064493
#
#    feature_761  feature_762  feature_763  feature_764  feature_765  \
# 0     0.128649    -0.187129     0.055629    -0.010358     0.125754
# 1     0.090799    -0.254056    -0.014893     0.071721     0.018918
# 2    -0.003885    -0.106426     0.012415     0.015215     0.083808
# 3     0.016679     0.047519    -0.078246    -0.032903     0.082949
# 4     0.177749    -0.117646    -0.094629     0.069718     0.014379
#
#    feature_766  feature_767  feature_768
# 0     0.011648     0.079197     0.093215
# 1     0.100032    -0.083042     0.088615
# 2     0.031312    -0.056277     0.064702
# 3    -0.020659     0.082274    -0.050164
# 4     0.048124     0.007586    -0.016980
#
# [5 rows x 768 columns]

# %%
y_label_1.head()
# Out:
# 0    45
# 1    45
# 2    45
# 3    45
# 4    45
# Name: label_1, dtype: int64

# %% [markdown]
# ##Class Distribution

# %%
import matplotlib.pyplot as plt

def plot_class_distribution(y):
  label_counts = y.value_counts()
  plt.figure(figsize=(12, 6))
  label_counts.plot(kind='bar')
  plt.xlabel('Value')
  plt.ylabel('Count')
  plt.title('Class Distribution')
  plt.xticks(rotation=45)
  plt.show()

# %%
plot_class_distribution(y_label_1)

# %% [markdown]
# `label 1` shows an even class distribition.

# %% [markdown]
# ##Feature Selection
# ###Check for columns with low variance

# %%
from sklearn.feature_selection import VarianceThreshold

def variance_check(x: pd.DataFrame, variance: float) -> []:
  try:
    var_thres = VarianceThreshold(variance)
    var_thres.fit(x)

    const_columns = [column for column in x.columns
                        if column not in x_label_1.columns[var_thres.get_support()]]

    print(f"The number of constant columns is {len(const_columns)}.")
    return const_columns

  except ValueError:
    print(f"No feature exists with variance grater than {variance}.")
    return []

# %%
const_columns_label_1 = variance_check(x_label_1, 0.3)
# Out:
# No feature exists with variance grater than 0.3.

# %%
const_columns_label_1 = variance_check(x_label_1, 0.2)
# Out:
# No feature exists with variance grater than 0.2.

# %%
const_columns_label_1 = variance_check(x_label_1, 0.18)
# Out:
# No feature exists with variance grater than 0.18.

# %%
const_columns_label_1 = variance_check(x_label_1, 0.17)
# Out:
# The number of constant columns is 767.

# %% [markdown]
# Almost all columns have lower variance than 0.17. Therefore, I could not take any feature selection decision based on the variance.

# %% [markdown]
# ###Check for correlation between features

# %%
def correlation_check(x: pd.DataFrame, threshold: float) -> set:
  correlated_features = set()
  correlation_matrix = x.corr()
  for i in range(len(x.columns)):
      for j in range(i):
          if abs(correlation_matrix.iloc[i, j]) > threshold:
              colname = correlation_matrix.columns[i]
              correlated_features.add(colname)
  return correlated_features

# %%
corr = correlation_check(x_label_1, 0.9)
print(len(corr))
# Out:
# 0

# %%
corr = correlation_check(x_label_1, 0.7)
print(len(corr))
# Out:
# 4

# %% [markdown]
# There are 4 features with correlation value greater than 0.7. Dropping those columns.

# %%
corr
# Out:
# {'feature_366', 'feature_396', 'feature_548', 'feature_620'}

# %%
x_label_1.drop(corr, axis = 1)
# Out:
#        feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0       0.186257  -0.058807   0.024632  -0.163933  -0.146699   0.035889
# 1       0.063431  -0.023597   0.068057  -0.252915  -0.061094  -0.027316
# 2       0.034962   0.035816  -0.029753  -0.094607  -0.017576  -0.053074
# 3       0.033772   0.085612   0.067488  -0.073953  -0.180646  -0.024512
# 4       0.134305   0.062096   0.106920  -0.089327   0.117093  -0.077107
# ...          ...        ...        ...        ...        ...        ...
# 28515   0.024453   0.044466  -0.049367  -0.065155  -0.109931  -0.089393
# 28516   0.016492   0.007850   0.004661  -0.068151  -0.120102  -0.018188
# 28517   0.024608   0.045056   0.011118  -0.055420  -0.180276  -0.075961
# 28518   0.174154  -0.068870   0.058101  -0.120567  -0.237380   0.024585
# 28519   0.069458   0.102667  -0.010687  -0.054117  -0.171478  -0.154001
#
#        feature_7  feature_8  feature_9  feature_10  ...  feature_759  \
# 0       0.111708  -0.162861   0.028249   -0.098063  ...    -0.135802
# 1       0.135747  -0.168147   0.091236   -0.078473  ...    -0.032524
# 2       0.040121  -0.007932   0.097872   -0.024042  ...    -0.016680
# 3       0.242879  -0.023374  -0.059999    0.002006  ...    -0.219269
# 4       0.152579   0.047529  -0.015998   -0.110657  ...    -0.228570
# ...          ...        ...        ...         ...  ...          ...
# 28515   0.003823   0.036797   0.142065    0.010630  ...     0.024859
# 28516   0.088983  -0.016272   0.057924   -0.091656  ...    -0.067817
# 28517   0.047853   0.043180   0.152698   -0.111217  ...    -0.066240
# 28518   0.187333  -0.100873   0.039363   -0.080888  ...     0.062747
# 28519   0.076675   0.025081   0.118611   -0.061732  ...    -0.130062
#
#        feature_760  feature_761  feature_762  feature_763  feature_764  \
# 0         0.101059     0.128649    -0.187129     0.055629    -0.010358
# 1         0.012977     0.090799    -0.254056    -0.014893     0.071721
# 2        -0.015495    -0.003885    -0.106426     0.012415     0.015215
# 3         0.065505     0.016679     0.047519    -0.078246    -0.032903
# 4         0.064493     0.177749    -0.117646    -0.094629     0.069718
# ...            ...          ...          ...          ...          ...
# 28515     0.034621     0.051483     0.055168    -0.037605    -0.009495
# 28516    -0.003412     0.120643    -0.156379    -0.043655    -0.065877
# 28517     0.146486     0.103236     0.060171     0.045422    -0.109505
# 28518     0.092733     0.099706     0.045776     0.028609    -0.081717
# 28519     0.153767     0.124336    -0.049092     0.118842    -0.177180
#
#        feature_765  feature_766  feature_767  feature_768
# 0         0.125754     0.011648     0.079197     0.093215
# 1         0.018918     0.100032    -0.083042     0.088615
# 2         0.083808     0.031312    -0.056277     0.064702
# 3         0.082949    -0.020659     0.082274    -0.050164
# 4         0.014379     0.048124     0.007586    -0.016980
# ...            ...          ...          ...          ...
# 28515     0.069628    -0.064233    -0.082123     0.068675
# 28516     0.114468     0.085360    -0.032404     0.076920
# 28517    -0.000356     0.022698     0.065250     0.017646
# 28518     0.089243     0.017368     0.044567     0.089306
# 28519     0.004411     0.034947     0.039597     0.031190
#
# [28520 rows x 764 columns]

# %%
x_valid_label_1.drop(corr, axis = 1)
# Out:
#      feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0     0.085129   0.000378  -0.029872  -0.104609  -0.191291  -0.025511
# 1     0.222652  -0.094210  -0.056387  -0.210214  -0.294624  -0.032355
# 2     0.072147   0.023575  -0.017664  -0.070988  -0.098729   0.018534
# 3     0.026623   0.052005  -0.006921  -0.075105  -0.074829  -0.031380
# 4     0.112069   0.113702   0.044343   0.010162  -0.169193  -0.099847
# ..         ...        ...        ...        ...        ...        ...
# 745   0.036486   0.073333   0.052712  -0.018089  -0.039885  -0.046212
# 746   0.058517   0.107909  -0.000917  -0.124313  -0.136299  -0.003659
# 747   0.019230  -0.076998   0.017446  -0.016700  -0.282224  -0.004379
# 748   0.074466   0.034260  -0.047654  -0.083071  -0.198895  -0.049708
# 749   0.181506  -0.019046   0.068383  -0.157177  -0.215584   0.065599
#
#      feature_7  feature_8  feature_9  feature_10  ...  feature_759  \
# 0     0.029381   0.006177   0.079207   -0.012729  ...    -0.020899
# 1    -0.069078  -0.172146   0.056509   -0.126757  ...    -0.159676
# 2     0.028282  -0.064789   0.094686   -0.067313  ...    -0.072512
# 3     0.012402  -0.043555   0.073825   -0.050979  ...     0.012509
# 4     0.195957   0.051861   0.024582    0.001314  ...    -0.173597
# ..         ...        ...        ...         ...  ...          ...
# 745   0.107208   0.004759   0.032059   -0.005685  ...    -0.171325
# 746   0.215999  -0.038392   0.067972   -0.013035  ...    -0.060771
# 747   0.197184  -0.013434   0.062925   -0.120180  ...    -0.052951
# 748  -0.023298  -0.029821   0.099372   -0.078732  ...     0.013639
# 749   0.141573  -0.149151   0.052901   -0.099507  ...     0.010061
#
#      feature_760  feature_761  feature_762  feature_763  feature_764  \
# 0       0.087778     0.083750     0.111214    -0.026701     0.003306
# 1       0.134823     0.139934     0.035135    -0.041096     0.013654
# 2       0.082791     0.017780     0.030908    -0.064602    -0.018653
# 3       0.010695     0.019255     0.010389    -0.005655     0.015477
# 4       0.247099     0.101261     0.127192    -0.118097    -0.043349
# ..           ...          ...          ...          ...          ...
# 745     0.000084    -0.010005    -0.245340     0.106053    -0.009913
# 746     0.064435     0.093060    -0.144935    -0.021046    -0.011035
# 747    -0.072245     0.051361    -0.094984    -0.047530    -0.091324
# 748     0.068534     0.040957    -0.015354    -0.031402    -0.035122
# 749     0.157955     0.097835    -0.205723    -0.037477     0.027741
#
#      feature_765  feature_766  feature_767  feature_768
# 0       0.052219     0.000784     0.004527     0.102033
# 1       0.142623    -0.011882     0.005219     0.143616
# 2       0.013636    -0.078994     0.060903     0.064752
# 3       0.064209     0.025045    -0.049599     0.078412
# 4       0.036754    -0.023065     0.007358    -0.132566
# ..           ...          ...          ...          ...
# 745     0.122847    -0.081883     0.019721    -0.077391
# 746     0.073465    -0.003446    -0.008054    -0.048233
# 747     0.014946    -0.087755     0.033582    -0.113840
# 748     0.043519    -0.019419     0.057408     0.046682
# 749     0.114189     0.017274     0.071658     0.054342
#
# [750 rows x 764 columns]

# %% [markdown]
# ###Mutual Information Classification

# %%
from sklearn.feature_selection import mutual_info_classif

def plot_mi(x: pd.DataFrame, y: pd.DataFrame) -> pd.Series:
  mi = pd.Series(mutual_info_classif(x, y))
  mi.sort_values(ascending=False).plot.bar(figsize=(32, 12))
  return mi

# %%
mi = plot_mi(x_label_1, y_label_1)

# %% [markdown]
# Observing the distribution of the graph, selecting features with mutual information scre greater than 0.06.

# %%
def feature_selection_cnt_mi(mi: pd.Series, threshold: float) -> int:
  no_of_selected_features = mi[mi > threshold].count()
  print (f"Selected {no_of_selected_features} features out of {len(mi)} features.")
  return no_of_selected_features

# %%
no_of_selected_features_label_1 = feature_selection_cnt_mi(mi, 0.06)
# Out:
# Selected 243 features out of 768 features.

# %%
from sklearn.feature_selection import SelectKBest

def feature_selection_mi(x: pd.DataFrame, y: pd.DataFrame, k: int) -> pd.DataFrame:
  selected_cols = SelectKBest(mutual_info_classif, k = k)
  selected_cols.fit(x, y)
  selected_col_names = x.columns[selected_cols.get_support()]
  print(selected_col_names)
  return selected_col_names

# %%
selected_col_names_label_1 = feature_selection_mi(x_label_1, y_label_1, no_of_selected_features_label_1)
# Out:
# Index(['feature_8', 'feature_13', 'feature_17', 'feature_23', 'feature_25',
#        'feature_27', 'feature_31', 'feature_33', 'feature_36', 'feature_40',
#        ...
#        'feature_733', 'feature_735', 'feature_738', 'feature_750',
#        'feature_753', 'feature_756', 'feature_757', 'feature_762',
#        'feature_763', 'feature_768'],
#       dtype='object', length=243)

# %%
x_label_1_selected = pd.DataFrame(x_label_1, columns = selected_col_names_label_1)
x_valid_label_1_selected = pd.DataFrame(x_valid_label_1, columns = selected_col_names_label_1)

# %% [markdown]
# ##Modelling
#
# ###Model Evaluation

# %%
from sklearn.metrics import confusion_matrix
import numpy as np

def eval_model(y_actual: pd.DataFrame, y_predicted: pd.DataFrame) -> float:
  cm = confusion_matrix(y_actual, y_predicted)
  fp = cm.sum(axis=0) - np.diag(cm)
  fn = cm.sum(axis=1) - np.diag(cm)
  tp = np.diag(cm)
  tn = cm.sum() - (fp + fn + tp)

  accuracy = (tp + tn) / (tp + fp + tn + fn)
  err_rate = (fp + fn) / (tp + fp + tn + fn)
  sensitivity = tp / (tp + fn)
  specificity = tn / (tn + fp)
  precision = tp / (tp + fp)

  recall = sensitivity
  f_score = (2 * precision * recall) / (precision + recall)

  print(f"Accuracy:      {accuracy[0]:.4f}")
  print(f"Error Rate:    {err_rate[0]:.4f}")
  print(f"Sensitivity:   {sensitivity[0]:.4f}")
  print(f"Specificity:   {specificity[0]:.4f}")
  print(f"Precision:     {precision[0]:.4f}")
  print(f"F1 Score:      {f_score[0]:.4f}")

  return f_score

# %% [markdown]
# ###KNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier

def knn_model(x_train: pd.DataFrame, y_train: pd.DataFrame, x_valid: pd.DataFrame, y_valid: pd.DataFrame, k: int):
  knn = KNeighborsClassifier(n_neighbors = k)
  knn.fit(x_train, y_train)
  y_pred = knn.predict(x_valid)
  f_score = eval_model(y_valid, y_pred)
  return [knn, f_score]

# %%
_, f_score_knn_label_1 = knn_model(x_label_1_selected, y_label_1, x_valid_label_1_selected, y_valid_label_1, 13)
# Out:
# Accuracy:      0.9987
# Error Rate:    0.0013
# Sensitivity:   0.9231
# Specificity:   1.0000
# Precision:     1.0000
# F1 Score:      0.9600

# %% [markdown]
# ###Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier

def rf_model(x_train: pd.DataFrame, y_train: pd.DataFrame, x_valid: pd.DataFrame, y_valid: pd.DataFrame, n_estimators: int, random_state: int):
  rf = RandomForestClassifier(n_estimators = n_estimators, random_state = random_state)
  rf.fit(x_train, y_train)
  y_pred = rf.predict(x_valid)
  f_score = eval_model(y_valid, y_pred)
  return [rf, f_score]

# %%
_, f_score_rf_label_1 = rf_model(x_label_1_selected, y_label_1, x_valid_label_1_selected, y_valid_label_1, 100, 42)
# Out:
# Accuracy:      0.9920
# Error Rate:    0.0080
# Sensitivity:   0.7692
# Specificity:   0.9959
# Precision:     0.7692
# F1 Score:      0.7692

# %% [markdown]
# ###XG Boost Model

# %%
import xgboost as xgb

def xgb_model_gpu(x_train, y_train, x_valid, y_valid, n_estimators, random_state):
    try:
        xgb_gpu = xgb.XGBClassifier(
            n_estimators = n_estimators,
            random_state = random_state,
            tree_method = 'gpu_hist',
            gpu_id = 0,
        )
        xgb_gpu.fit(x_train, y_train)
        y_pred = xgb_gpu.predict(x_valid)
        f_score = eval_model(y_valid, y_pred)
        return [xgb_gpu, f_score]
    except ValueError:
        y_train_cpy = y_train.copy(deep=True)
        y_valid_cpy = y_valid.copy(deep=True)
        y_train_cpy = y_train_cpy - 1
        y_valid_cpy = y_valid_cpy - 1
        xgb_gpu = xgb.XGBClassifier(
            n_estimators = n_estimators,
            random_state = random_state,
            tree_method = 'gpu_hist',
            gpu_id = 0,
        )
        xgb_gpu.fit(x_train, y_train_cpy)
        y_pred = xgb_gpu.predict(x_valid)
        f_score = eval_model(y_valid_cpy, y_pred)
        return [xgb_gpu, f_score]

# %%
_, f_score_xgb_label_1 = xgb_model_gpu(x_label_1_selected, y_label_1, x_valid_label_1_selected, y_valid_label_1, 50, 42)
# Out:
# Accuracy:      0.9960
# Error Rate:    0.0040
# Sensitivity:   0.7692
# Specificity:   1.0000
# Precision:     1.0000
# F1 Score:      0.8696

# %% [markdown]
# ###XGBoost Model

# %%
from sklearn.svm import SVC

def svm_model(x_train: pd.DataFrame, y_train: pd.DataFrame, x_valid: pd.DataFrame, y_valid: pd.DataFrame, kernel: str):
  svm = SVC(kernel = kernel)
  svm.fit(x_train, y_train)
  y_pred = svm.predict(x_valid)
  f_score = eval_model(y_valid, y_pred)
  return [svm, f_score]

# %%
f_scores_svm_label_1 = []
kernels = ["linear", "rbf", "poly"]

for i in range(3):
  kernel = kernels[i]
  print(kernel.capitalize())
  _, f_sc = svm_model(x_label_1_selected, y_label_1, x_valid_label_1_selected, y_valid_label_1, kernel)
  f_scores_svm_label_1.append([kernel, f_sc])
  if (i!= 2): print()
# Out:
# Linear
# Accuracy:      0.9987
# Error Rate:    0.0013
# Sensitivity:   0.9231
# Specificity:   1.0000
# Precision:     1.0000
# F1 Score:      0.9600
#
# Rbf
# Accuracy:      0.9987
# Error Rate:    0.0013
# Sensitivity:   0.9231
# Specificity:   1.0000
# Precision:     1.0000
# F1 Score:      0.9600
#
# Poly
# Accuracy:      0.9987
# Error Rate:    0.0013
# Sensitivity:   0.9231
# Specificity:   1.0000
# Precision:     1.0000
# F1 Score:      0.9600
